# %%
import pandas as pd

# %%
house=pd.read_csv("House Price India.csv")
house
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810635  42491                   4                 2.50
# 1      6762810998  42491                   5                 2.75
# 2      6762812605  42491                   4                 2.50
# 3      6762812919  42491                   3                 2.00
# 4      6762813105  42491                   3                 2.50
# ...           ...    ...                 ...                  ...
# 14614  6762830250  42734                   2                 1.50
# 14615  6762830339  42734                   3                 2.00
# 14616  6762830618  42734                   2                 1.00
# 14617  6762830709  42734                   4                 1.00
# 14618  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             2920      4000               1.5                   0
# ...

# %%
house.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14619 entries, 0 to 14618
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14619 non-null  int64
#  1   Date                                   14619 non-null  int64
#  2   number of bedrooms                     14619 non-null  int64
#  3   number of bathrooms                    14619 non-null  float64
#  4   living area                            14619 non-null  int64
#  5   lot area                               14619 non-null  int64
#  6   number of floors                       14619 non-null  float64
#  7   waterfront present                     14619 non-null  int64
#  8   number of views                        14619 non-null  int64
#  9   condition of the house                 14619 non-null  int64
# ...

# %%
house.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.461900e+04  14619.000000        14619.000000         14619.000000
# mean   6.762821e+09  42604.546412            3.379233             2.129557
# std    6.237162e+03     67.343747            0.938655             0.769955
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14619.000000  1.461900e+04      14619.000000        14619.000000
# mean    2098.156851  1.509369e+04          1.502326            0.007661
# std      928.218740  3.792089e+04          0.540241            0.087196
# ...

# %%
stats =house["Price"].describe().reset_index()
stats["Price"]=round(stats["Price"],2)

# %%
stats
# Out:
#    index       Price
# 0  count    14619.00
# 1   mean   538806.28
# 2    std   367229.36
# 3    min    78000.00
# 4    25%   320000.00
# 5    50%   450000.00
# 6    75%   645000.00
# 7    max  7700000.00

# %%
house.isnull().sum().sum()
# Out:
# 0

# %%
house.duplicated().sum()
# Out:
# 0

# %%
#removimg the null values
house.dropna(inplace= True)
#removing the duplicate values
house.drop_duplicates(inplace=True)

# %%
house.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
house.groupby("condition of the house")["Price"].mean().sort_values(ascending=True).plot(kind='bar')
plt.title("Condition of the house vs prices")
plt.ylabel("Mean Prices")
plt.xlabel("Condition of the house")
plt.show()

# %%
x =house[["number of bedrooms","number of bathrooms","living area","condition of the house",'Number of schools nearby']]
y =house[["Price"]]

# %%
x
# Out:
#        number of bedrooms  number of bathrooms  living area  \
# 0                       4                 2.50         2920
# 1                       5                 2.75         2910
# 2                       4                 2.50         3310
# 3                       3                 2.00         2710
# 4                       3                 2.50         2600
# ...                   ...                  ...          ...
# 14614                   2                 1.50         1556
# 14615                   3                 2.00         1680
# 14616                   2                 1.00         1070
# 14617                   4                 1.00         1030
# 14618                   3                 1.00          900
#
#        condition of the house  Number of schools nearby
# 0                           5                         2
# 1                           3                         1
# 2                           3                         3
# ...

# %%
y
# Out:
#          Price
# 0      1400000
# 1      1200000
# 2       838000
# 3       805000
# 4       790000
# ...        ...
# 14614   221700
# 14615   219200
# 14616   209000
# 14617   205000
# 14618   146000
#
# [14619 rows x 1 columns]

# %%
house.shape[0] * 0.8
# Out:
# 11695.2

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y, test_size=0.2)

# %%
x_train.shape
# Out:
# (11695, 5)

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.tree import DecisionTreeRegressor
param_grid = {
    "criterion": ["mse","friedman_mse","mae"],
    "splitter": ["best","random"],
    "max_depth" : [None,10,20,30,40,50],
    "min_samples_split" : [2,5,10],
    "min_samples_leaf" : [1,2,4]
}

# %%
tree_model =DecisionTreeRegressor()

# %%
grid_tree= GridSearchCV(estimator =tree_model,param_grid=param_grid)

# %%
grid_tree.fit(x_train,y_train)

# %%
grid_tree.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 10,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'splitter': 'random'}

# %%
tree_pred =grid_tree.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test,tree_pred)
# Out:
# 161260.13240839852

# %%
from sklearn.linear_model import LinearRegression
Lr=LinearRegression()

# %%
Lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predlr= Lr.predict(x_test)

# %%
mean_absolute_error(y_test,predlr)
# Out:
# 163006.19588978591

# %%
from sklearn.ensemble import RandomForestRegressor
rfmodel= RandomForestRegressor()

# %%
param_gridrf={
    "max_depth":[5,10,15],
    "n_estimators":[2,3,4,5,6,7,8,9,10]
}

# %%
gridrfr = GridSearchCV(rfmodel,param_gridrf)

# %%
gridrfr.fit(x_train,y_train)
# Out:
# c:\Users\Shuhaib\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\Shuhaib\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# c:\Users\Shuhaib\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ...

# %%
gridrfr.fit(x_train,y_train.values.ravel())
# Out:
# GridSearchCV(estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [5, 10, 15],
#                          'n_estimators': [2, 3, 4, 5, 6, 7, 8, 9, 10]})

# %%
gridrfr.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 9}

# %%
rfpred= gridrfr.predict(x_test)

# %%
mean_absolute_error(y_test,rfpred)
# Out:
# 157601.04459712986

# %%
import joblib

# %%
joblib.dump(grid_tree,"model.pkl")
# Out:
# ['model.pkl']
